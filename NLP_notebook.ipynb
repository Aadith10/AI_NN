# %%
import pandas as pd
import numpy as np

# %%
input = {2,3,4,5}
weights = {0.1, 0.2, 0.3, 0.4}
bias = 2

output = (input[0]*weights[0]+
          input[1]+weights[1]+
          input[2]*weights[2]+
          input[3]*weights[3]+
          bias)

output = max(0,output)
print(output)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 input = {2,3,4,5}
#       2 weights = {0.1, 0.2, 0.3, 0.4}
#       3 bias = 2
#       4
# ----> 5 output = (input[0]*weights[0]+
#       6           input[1]+weights[1]+
#       7           input[2]*weights[2]+
#       8           input[3]*weights[3]+
#
# TypeError: 'set' object is not subscriptable

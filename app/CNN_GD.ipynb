# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780926301.936524   55200 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780926301.953130   55200 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1780926303.800537   55200 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780926312.416860   55200 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1780926312.418335   55200 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32') / 255
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32') / 255
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
def build_model(optimizer):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))
    
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=optimizer,
                  metrics=['accuracy'])
    return model

# %%
optimizers = ['Adam', 'sgd', 'RMSprop', 'adagrad', 'adadelta']
history_dic = {}
for opt in optimizers:
    print(f"Training with optimizer: {opt}")
    model = build_model(opt)
    history = model.fit(x_train, y_train, batch_size=64, epochs=5, verbose=1, validation_data=(x_test, y_test))
    history_dic[opt] = history.history
# Out:
# Training with optimizer: Adam
# /workspaces/AI_NN/.venv/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1780926805.051533   55200 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 92s 97ms/step - accuracy: 0.9469 - loss: 0.1725 - val_accuracy: 0.9829 - val_loss: 0.0493
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.9807 - loss: 0.0628 - val_accuracy: 0.9884 - val_loss: 0.0356
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 88ms/step - accuracy: 0.9860 - loss: 0.0464 - val_accuracy: 0.9899 - val_loss: 0.0318
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 90s 96ms/step - accuracy: 0.9874 - loss: 0.0387 - val_accuracy: 0.9905 - val_loss: 0.0285
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 88s 94ms/step - accuracy: 0.9897 - loss: 0.0310 - val_accuracy: 0.9894 - val_loss: 0.0310
# Training with optimizer: sgd
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 78s 82ms/step - accuracy: 0.7665 - loss: 0.7662 - val_accuracy: 0.9283 - val_loss: 0.2464
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 80ms/step - accuracy: 0.9054 - loss: 0.3078 - val_accuracy: 0.9498 - val_loss: 0.1713
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 78s 83ms/step - accuracy: 0.9255 - loss: 0.2457 - val_accuracy: 0.9618 - val_loss: 0.1348
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 76s 77ms/step - accuracy: 0.9353 - loss: 0.2111 - val_accuracy: 0.9645 - val_loss: 0.1214
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 78ms/step - accuracy: 0.9426 - loss: 0.1894 - val_accuracy: 0.9667 - val_loss: 0.1069
# Training with optimizer: RMSprop
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 79s 83ms/step - accuracy: 0.9469 - loss: 0.1716 - val_accuracy: 0.9815 - val_loss: 0.0552
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 76s 81ms/step - accuracy: 0.9810 - loss: 0.0631 - val_accuracy: 0.9876 - val_loss: 0.0380
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 83s 82ms/step - accuracy: 0.9857 - loss: 0.0477 - val_accuracy: 0.9881 - val_loss: 0.0347
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 84s 84ms/step - accuracy: 0.9877 - loss: 0.0395 - val_accuracy: 0.9901 - val_loss: 0.0307
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 76s 81ms/step - accuracy: 0.9894 - loss: 0.0354 - val_accuracy: 0.9907 - val_loss: 0.0283
# Training with optimizer: adagrad
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 85s 90ms/step - accuracy: 0.6350 - loss: 1.2086 - val_accuracy: 0.8892 - val_loss: 0.4095
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 75s 80ms/step - accuracy: 0.8453 - loss: 0.5031 - val_accuracy: 0.9131 - val_loss: 0.3035
# Epoch 3/5
# 537/938 ━━━━━━━━━━━━━━━━━━━━ 42s 105ms/step - accuracy: 0.8641 - loss: 0.4381

# %%
import matplotlib.pyplot as plt
for opt in optimizers:
    plt.plot(history_dic[opt].history['val_acc'], label = opt)
plt.title('Validation Accuracy for Different Optimizers')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
